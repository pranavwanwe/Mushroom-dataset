# %% [markdown]
# ### Importing Data

# %%
import pandas as pd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv(r'Downloads\mushrooms.csv')

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %% [markdown]
# ### Exploring Data

# %%
df.describe().T
# Out:
#                          count unique top  freq
# class                     8124      2   e  4208
# cap-shape                 8124      6   x  3656
# cap-surface               8124      4   y  3244
# cap-color                 8124     10   n  2284
# bruises                   8124      2   f  4748
# odor                      8124      9   n  3528
# gill-attachment           8124      2   f  7914
# gill-spacing              8124      2   c  6812
# gill-size                 8124      2   b  5612
# gill-color                8124     12   b  1728
# stalk-shape               8124      2   t  4608
# stalk-root                8124      5   b  3776
# stalk-surface-above-ring  8124      4   s  5176
# stalk-surface-below-ring  8124      4   s  4936
# stalk-color-above-ring    8124      9   w  4464
# stalk-color-below-ring    8124      9   w  4384
# veil-type                 8124      1   p  8124
# veil-color                8124      4   w  7924
# ring-number               8124      3   o  7488
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 23 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   object
#  1   cap-shape                 8124 non-null   object
#  2   cap-surface               8124 non-null   object
#  3   cap-color                 8124 non-null   object
#  4   bruises                   8124 non-null   object
#  5   odor                      8124 non-null   object
#  6   gill-attachment           8124 non-null   object
#  7   gill-spacing              8124 non-null   object
#  8   gill-size                 8124 non-null   object
#  9   gill-color                8124 non-null   object
#  10  stalk-shape               8124 non-null   object
#  11  stalk-root                8124 non-null   object
#  12  stalk-surface-above-ring  8124 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df['class'].value_counts()
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64

# %%
# As we can see the data is categorical 
# There are no null values 
# As we can see the E and P values are balanced so we can say that the data is balanced

# %%
for i in df.columns:
    df[i]=df[i].astype('category')
    print(df[i].value_counts())
    print('='*50)
# Out:
# e    4208
# p    3916
# Name: class, dtype: int64
# ...
# x    3656
# f    3152
# k     828
# b     452
# s      32
# c       4
# Name: cap-shape, dtype: int64
# ...
# y    3244
# s    2556
# f    2320
# g       4
# Name: cap-surface, dtype: int64
# ...
# n    2284
# g    1840
# e    1500
# y    1072
# w    1040
# b     168
# p     144
# c      44
# r      16
# u      16
# Name: cap-color, dtype: int64
# ...
# f    4748
# t    3376
# Name: bruises, dtype: int64
# ...
# n    3528
# f    2160
# s     576
# y     576
# a     400
# l     400
# p     256
# c     192
# m      36
# Name: odor, dtype: int64
# ...
# f    7914
# a     210
# Name: gill-attachment, dtype: int64
# ...
# c    6812
# w    1312
# Name: gill-spacing, dtype: int64
# ...
# b    5612
# n    2512
# Name: gill-size, dtype: int64
# ...
# b    1728
# p    1492
# w    1202
# n    1048
# g     752
# h     732
# u     492
# k     408
# e      96
# y      86
# o      64
# r      24
# Name: gill-color, dtype: int64
# ...
# t    4608
# e    3516
# Name: stalk-shape, dtype: int64
# ...

# %%
# there are 8124 records of single category so we will drop that variable 
# there are 2480 records as ? in stalk-root are those missing values? we will see it?
# most features are unbalanced between their properties, there are some common and some are very rare properties

# %%
df.drop(columns='veil-type',inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8124 entries, 0 to 8123
# Data columns (total 22 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   class                     8124 non-null   category
#  1   cap-shape                 8124 non-null   category
#  2   cap-surface               8124 non-null   category
#  3   cap-color                 8124 non-null   category
#  4   bruises                   8124 non-null   category
#  5   odor                      8124 non-null   category
#  6   gill-attachment           8124 non-null   category
#  7   gill-spacing              8124 non-null   category
#  8   gill-size                 8124 non-null   category
#  9   gill-color                8124 non-null   category
#  10  stalk-shape               8124 non-null   category
#  11  stalk-root                8124 non-null   category
#  12  stalk-surface-above-ring  8124 non-null   category
# ...

# %% [markdown]
# ### Visualisation

# %%
fig, axes = plt.subplots(nrows=7,ncols=3, figsize=(20,50),sharey=True)
idx = 0
for col in df.columns[1:]:
    sns.countplot(data=df,x=col, hue='class' ,ax=axes[idx//3][idx%3])
    idx += 1

# %% [markdown]
# The ? category present in stalk-root is most likely to be poisonous so we wont consider those as missing values.

# %% [markdown]
# ### Preprocessing

# %%
# lable encoding them using lable encoder 
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

for i in df.columns:
    df[i]=le.fit_transform(df[i])

# %%
df.head()
# Out:
#    class  cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0      1          5            2          4        1     6                1
# 1      0          5            2          9        1     0                1
# 2      0          0            2          8        1     3                1
# 3      1          5            3          8        1     6                1
# 4      0          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  ...  stalk-surface-above-ring  \
# 0             0          1           4  ...                         2
# 1             0          0           4  ...                         2
# 2             0          0           5  ...                         2
# 3             0          1           5  ...                         2
# 4             1          0           4  ...                         2
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# ...

# %% [markdown]
# ### Splitting data into X and Y

# %%
X = df.iloc[:,1:]
Y = df['class']

X.head(5)
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk-surface-above-ring  stalk-surface-below-ring  stalk-color-above-ring  \
# 0                         2                         2                       7
# ...

# %%
Y.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    1
# 4    0
# Name: class, dtype: int32

# %% [markdown]
# ### The data is now encoded

# %% [markdown]
# ### Making split for training and testing

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size=0.2)

# %%
X_test.shape
# Out:
# (1625, 21)

# %%
X_train.shape
# Out:
# (6499, 21)

# %% [markdown]
# ### Applying logistic regression

# %%
from sklearn.linear_model import LogisticRegression

model_lr = LogisticRegression(max_iter=1000)

model_lr.fit(X_train,Y_train)

Y_pred = model_lr.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

print("confusion matrix", confusion_matrix(Y_test,Y_pred))
print("classification report:", classification_report(Y_test,Y_pred))
print("accuracy score:", accuracy_score(Y_test,Y_pred)*100)
# Out:
# confusion matrix [[758  40]
#  [ 36 791]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       798
#            1       0.95      0.96      0.95       827
#
#     accuracy                           0.95      1625
#    macro avg       0.95      0.95      0.95      1625
# weighted avg       0.95      0.95      0.95      1625
#
# accuracy score: 95.32307692307693

# %% [markdown]
# ### With logistic regression we got 95.32% accuracy, Let's now try SVC

# %%
from sklearn.svm import SVC

model_svc = SVC()

model_svc.fit(X_train,Y_train)

Y_pred = model_svc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

print("confusion matrix", confusion_matrix(Y_test,Y_pred))
print("classification report:", classification_report(Y_test,Y_pred))
print("accuracy score:", accuracy_score(Y_test,Y_pred)*100)
# Out:
# confusion matrix [[796   2]
#  [ 12 815]]
# classification report:               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       798
#            1       1.00      0.99      0.99       827
#
#     accuracy                           0.99      1625
#    macro avg       0.99      0.99      0.99      1625
# weighted avg       0.99      0.99      0.99      1625
#
# accuracy score: 99.13846153846154

# %% [markdown]
# ### With SVC we have got 99.13% of accuracy, now let's try KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

model_knn = KNeighborsClassifier()

model_knn.fit(X_train,Y_train)

Y_pred = model_knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

print("confusion matrix", confusion_matrix(Y_test,Y_pred))
print("classification report:", classification_report(Y_test,Y_pred))
print("accuracy score:", accuracy_score(Y_test,Y_pred)*100)
# Out:
# confusion matrix [[795   3]
#  [  0 827]]
# classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       798
#            1       1.00      1.00      1.00       827
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625
#
# accuracy score: 99.81538461538462

# %% [markdown]
# ### With KNN we have got some increase in accuracy that is 99.81%, Let's try decision tree classifier

# %%
from sklearn.tree import DecisionTreeClassifier

model_dt = DecisionTreeClassifier()

model_dt.fit(X_train,Y_train)

Y_pred = model_dt.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,classification_report

print("confusion matrix", confusion_matrix(Y_test,Y_pred))
print("classification report:", classification_report(Y_test,Y_pred))
print("accuracy score:", accuracy_score(Y_test,Y_pred)*100)
# Out:
# confusion matrix [[798   0]
#  [  0 827]]
# classification report:               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       798
#            1       1.00      1.00      1.00       827
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625
#
# accuracy score: 100.0

# %% [markdown]
# ### With Decision tree classifier we have got 100% accuracy
